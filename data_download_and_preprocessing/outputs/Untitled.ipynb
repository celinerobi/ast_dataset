# %%
import fiona
import os 
import pandas as pd
import geopandas as gpd

# %%
quad_indicies_path = "C:/Users/rapiduser/Box/EPA STAR 2019 (Community Resistance to Environmental Disasters)/Data/AST Datasets/MapIndices_National_GDB/MapIndices_National_GDB.gdb"
fiona.listlayers(quad_indicies_path)
# Out:
# ['Cell_Features',
#  'Cell_History',
#  'CellGrid_15Minute',
#  'CellGrid_1X1Degree',
#  'CellGrid_1X2Degree',
#  'CellGrid_3_75Minute',
#  'CellGrid_30X60Minute',
#  'CellGrid_7_5Minute',
#  'Cell_PolygonAll']

# %%
# Download from https://data.cityofnewyork.us/City-Government/Projected-Sea-Level-Rise/6an6-9htp directly...
data = gpd.read_file(quad_indicies_path, driver='FileGDB', layer=7)#'CellGrid_7_5Minute')

# %%
pd.DataFrame(data)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# C:\ProgramData\Anaconda3\envs\chip_allocate\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# C:\ProgramData\Anaconda3\envs\chip_allocate\lib\site-packages\IPython\lib\pretty.py in pretty(self, obj)
#     392                         if cls is not object \
#     393                                 and callable(cls.__dict__.get('__repr__')):
# --> 394                             return _repr_pprint(obj, self, cycle)
#     395
#     396             return _default_pprint(obj, self, cycle)
#
# C:\ProgramData\Anaconda3\envs\chip_allocate\lib\site-packages\IPython\lib\pretty.py in _repr_pprint(obj, p, cycle)
#     698     """A pprint that just redirects to the normal repr function."""
#     699     # Find newlines and replace them with p.break_()
# --> 700     output = repr(obj)
#     701     lines = output.splitlines()
#     702     with p.group():
#
# C:\ProgramData\Anaconda3\envs\chip_allocate\lib\site-packages\pandas\core\frame.py in __repr__(self)
#     993         else:
#     994             width = None
# --> 995         self.to_string(
#     996             buf=buf,
#     997             max_rows=max_rows,
#
# C:\ProgramData\Anaconda3\envs\chip_allocate\lib\site-packages\pandas\core\frame.py in to_string(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, max_rows, min_rows, max_cols, show_dimensions, decimal, line_width, max_colwidth, encoding)
#    1129                 decimal=decimal,
#    1130             )
# -> 1131             return fmt.DataFrameRenderer(formatter).to_string(
#    1132                 buf=buf,
#    1133                 encoding=encoding,
#
# C:\ProgramData\Anaconda3\envs\chip_allocate\lib\site-packages\pandas\io\formats\format.py in to_string(self, buf, encoding, line_width)
#    1051
#    1052         string_formatter = StringFormatter(self.fmt, line_width=line_width)
# -> 1053         string = string_formatter.to_string()
#    1054         return save_to_buffer(string, buf=buf, encoding=encoding)
#    1055
#
# C:\ProgramData\Anaconda3\envs\chip_allocate\lib\site-packages\pandas\io\formats\string.py in to_string(self)
#      23
#      24     def to_string(self) -> str:
# ---> 25         text = self._get_string_representation()
#      26         if self.fmt.should_show_dimensions:
#      27             text = "".join([text, self.fmt.dimensions_info])
#
# C:\ProgramData\Anaconda3\envs\chip_allocate\lib\site-packages\pandas\io\formats\string.py in _get_string_representation(self)
#      38             return self._empty_info_line
#      39
# ---> 40         strcols = self._get_strcols()
#      41
#      42         if self.line_width is None:
#
# C:\ProgramData\Anaconda3\envs\chip_allocate\lib\site-packages\pandas\io\formats\string.py in _get_strcols(self)
#      29
#      30     def _get_strcols(self) -> list[list[str]]:
# ---> 31         strcols = self.fmt.get_strcols()
#      32         if self.fmt.is_truncated:
#      33             strcols = self._insert_dot_separators(strcols)
#
# C:\ProgramData\Anaconda3\envs\chip_allocate\lib\site-packages\pandas\io\formats\format.py in get_strcols(self)
#     538         Render a DataFrame to a list of columns (as lists of strings).
#     539         """
# --> 540         strcols = self._get_strcols_without_index()
#     541
#     542         if self.index:
#
# C:\ProgramData\Anaconda3\envs\chip_allocate\lib\site-packages\pandas\io\formats\format.py in _get_strcols_without_index(self)
#     802                 int(self.col_space.get(c, 0)), *(self.adj.len(x) for x in cheader)
#     803             )
# --> 804             fmt_values = self.format_col(i)
#     805             fmt_values = _make_fixed_width(
#     806                 fmt_values, self.justify, minimum=header_colwidth, adj=self.adj
#
# C:\ProgramData\Anaconda3\envs\chip_allocate\lib\site-packages\pandas\io\formats\format.py in format_col(self, i)
#     816         frame = self.tr_frame
#     817         formatter = self._get_formatter(i)
# --> 818         return format_array(
#     819             frame.iloc[:, i]._values,
#     820             formatter,
#
# C:\ProgramData\Anaconda3\envs\chip_allocate\lib\site-packages\pandas\io\formats\format.py in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space, quoting)
#    1238     )
#    1239
# -> 1240     return fmt_obj.get_result()
#    1241
#    1242
#
# C:\ProgramData\Anaconda3\envs\chip_allocate\lib\site-packages\pandas\io\formats\format.py in get_result(self)
#    1269
#    1270     def get_result(self) -> list[str]:
# -> 1271         fmt_values = self._format_strings()
#    1272         return _make_fixed_width(fmt_values, self.justify)
#    1273
#
# C:\ProgramData\Anaconda3\envs\chip_allocate\lib\site-packages\pandas\io\formats\format.py in _format_strings(self)
#    1574             array = np.asarray(values)
#    1575
# -> 1576         fmt_values = format_array(
#    1577             array,
#    1578             formatter,
#
# C:\ProgramData\Anaconda3\envs\chip_allocate\lib\site-packages\pandas\io\formats\format.py in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space, quoting)
#    1238     )
#    1239
# -> 1240     return fmt_obj.get_result()
#    1241
#    1242
#
# C:\ProgramData\Anaconda3\envs\chip_allocate\lib\site-packages\pandas\io\formats\format.py in get_result(self)
#    1269
#    1270     def get_result(self) -> list[str]:
# -> 1271         fmt_values = self._format_strings()
#    1272         return _make_fixed_width(fmt_values, self.justify)
#    1273
#
# C:\ProgramData\Anaconda3\envs\chip_allocate\lib\site-packages\pandas\io\formats\format.py in _format_strings(self)
#    1332         for i, v in enumerate(vals):
#    1333             if not is_float_type[i] and leading_space:
# -> 1334                 fmt_values.append(f" {_format(v)}")
#    1335             elif is_float_type[i]:
#    1336                 fmt_values.append(float_format(v))
#
# C:\ProgramData\Anaconda3\envs\chip_allocate\lib\site-packages\pandas\io\formats\format.py in _format(x)
#    1312             else:
#    1313                 # object dtype
# -> 1314                 return str(formatter(x))
#    1315
#    1316         vals = extract_array(self.values, extract_numpy=True)
#
# C:\ProgramData\Anaconda3\envs\chip_allocate\lib\site-packages\geopandas\array.py in <lambda>(geom)
#    1283                         # (in case of unit meter: mm precision)
#    1284                         precision = 3
# -> 1285             return lambda geom: shapely.wkt.dumps(geom, rounding_precision=precision)
#    1286         return repr
#    1287
#
# C:\ProgramData\Anaconda3\envs\chip_allocate\lib\site-packages\shapely\wkt.py in dumps(ob, trim, **kw)
#      60     input geometry as WKT string
#      61     """
# ---> 62     return geos.WKTWriter(geos.lgeos, trim=trim, **kw).write(ob)
#      63
#      64
#
# C:\ProgramData\Anaconda3\envs\chip_allocate\lib\site-packages\shapely\geos.py in write(self, geom)
#     378         if geom is None or geom._geom is None:
#     379             raise ValueError("Null geometry supports no operations")
# --> 380         result = self._lgeos.GEOSWKTWriter_write(self._writer, geom._geom)
#     381         text = string_at(result)
#     382         lgeos.GEOSFree(result)
#
# OSError: exception: access violation writing 0x0000000000000000
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# C:\ProgramData\Anaconda3\envs\chip_allocate\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# C:\ProgramData\Anaconda3\envs\chip_allocate\lib\site-packages\pandas\core\frame.py in _repr_html_(self)
#    1045                 decimal=".",
#    1046             )
# -> 1047             return fmt.DataFrameRenderer(formatter).to_html(notebook=True)
#    1048         else:
#    1049             return None
#
# C:\ProgramData\Anaconda3\envs\chip_allocate\lib\site-packages\pandas\io\formats\format.py in to_html(self, buf, encoding, classes, notebook, border, table_id, render_links)
#    1027             render_links=render_links,
#    1028         )
# -> 1029         string = html_formatter.to_string()
#    1030         return save_to_buffer(string, buf=buf, encoding=encoding)
#    1031
#
# C:\ProgramData\Anaconda3\envs\chip_allocate\lib\site-packages\pandas\io\formats\html.py in to_string(self)
#      70
#      71     def to_string(self) -> str:
# ---> 72         lines = self.render()
#      73         if any(isinstance(x, str) for x in lines):
#      74             lines = [str(x) for x in lines]
#
# C:\ProgramData\Anaconda3\envs\chip_allocate\lib\site-packages\pandas\io\formats\html.py in render(self)
#     619         self.write("<div>")
#     620         self.write_style()
# --> 621         super().render()
#     622         self.write("</div>")
#     623         return self.elements
#
# C:\ProgramData\Anaconda3\envs\chip_allocate\lib\site-packages\pandas\io\formats\html.py in render(self)
#      76
#      77     def render(self) -> list[str]:
# ---> 78         self._write_table()
#      79
#      80         if self.should_show_dimensions:
#
# C:\ProgramData\Anaconda3\envs\chip_allocate\lib\site-packages\pandas\io\formats\html.py in _write_table(self, indent)
#     246             self._write_header(indent + self.indent_delta)
#     247
# --> 248         self._write_body(indent + self.indent_delta)
#     249
#     250         self.write("</table>", indent)
#
# C:\ProgramData\Anaconda3\envs\chip_allocate\lib\site-packages\pandas\io\formats\html.py in _write_body(self, indent)
#     393     def _write_body(self, indent: int) -> None:
#     394         self.write("<tbody>", indent)
# --> 395         fmt_values = self._get_formatted_values()
#     396
#     397         # write values
#
# C:\ProgramData\Anaconda3\envs\chip_allocate\lib\site-packages\pandas\io\formats\html.py in _get_formatted_values(self)
#     583
#     584     def _get_formatted_values(self) -> dict[int, list[str]]:
# --> 585         return {i: self.fmt.format_col(i) for i in range(self.ncols)}
#     586
#     587     def _get_columns_formatted_values(self) -> list[str]:
#
# C:\ProgramData\Anaconda3\envs\chip_allocate\lib\site-packages\pandas\io\formats\html.py in <dictcomp>(.0)
#     583
#     584     def _get_formatted_values(self) -> dict[int, list[str]]:
# --> 585         return {i: self.fmt.format_col(i) for i in range(self.ncols)}
#     586
#     587     def _get_columns_formatted_values(self) -> list[str]:
#
# C:\ProgramData\Anaconda3\envs\chip_allocate\lib\site-packages\pandas\io\formats\format.py in format_col(self, i)
#     816         frame = self.tr_frame
#     817         formatter = self._get_formatter(i)
# --> 818         return format_array(
#     819             frame.iloc[:, i]._values,
#     820             formatter,
#
# C:\ProgramData\Anaconda3\envs\chip_allocate\lib\site-packages\pandas\io\formats\format.py in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space, quoting)
#    1238     )
#    1239
# -> 1240     return fmt_obj.get_result()
#    1241
#    1242
#
# C:\ProgramData\Anaconda3\envs\chip_allocate\lib\site-packages\pandas\io\formats\format.py in get_result(self)
#    1269
#    1270     def get_result(self) -> list[str]:
# -> 1271         fmt_values = self._format_strings()
#    1272         return _make_fixed_width(fmt_values, self.justify)
#    1273
#
# C:\ProgramData\Anaconda3\envs\chip_allocate\lib\site-packages\pandas\io\formats\format.py in _format_strings(self)
#    1574             array = np.asarray(values)
#    1575
# -> 1576         fmt_values = format_array(
#    1577             array,
#    1578             formatter,
#
# C:\ProgramData\Anaconda3\envs\chip_allocate\lib\site-packages\pandas\io\formats\format.py in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space, quoting)
#    1238     )
#    1239
# -> 1240     return fmt_obj.get_result()
#    1241
#    1242
#
# C:\ProgramData\Anaconda3\envs\chip_allocate\lib\site-packages\pandas\io\formats\format.py in get_result(self)
#    1269
#    1270     def get_result(self) -> list[str]:
# -> 1271         fmt_values = self._format_strings()
#    1272         return _make_fixed_width(fmt_values, self.justify)
#    1273
#
# C:\ProgramData\Anaconda3\envs\chip_allocate\lib\site-packages\pandas\io\formats\format.py in _format_strings(self)
#    1332         for i, v in enumerate(vals):
#    1333             if not is_float_type[i] and leading_space:
# -> 1334                 fmt_values.append(f" {_format(v)}")
#    1335             elif is_float_type[i]:
#    1336                 fmt_values.append(float_format(v))
#
# C:\ProgramData\Anaconda3\envs\chip_allocate\lib\site-packages\pandas\io\formats\format.py in _format(x)
#    1312             else:
#    1313                 # object dtype
# -> 1314                 return str(formatter(x))
#    1315
#    1316         vals = extract_array(self.values, extract_numpy=True)
#
# C:\ProgramData\Anaconda3\envs\chip_allocate\lib\site-packages\geopandas\array.py in <lambda>(geom)
#    1283                         # (in case of unit meter: mm precision)
#    1284                         precision = 3
# -> 1285             return lambda geom: shapely.wkt.dumps(geom, rounding_precision=precision)
#    1286         return repr
#    1287
#
# C:\ProgramData\Anaconda3\envs\chip_allocate\lib\site-packages\shapely\wkt.py in dumps(ob, trim, **kw)
#      60     input geometry as WKT string
#      61     """
# ---> 62     return geos.WKTWriter(geos.lgeos, trim=trim, **kw).write(ob)
#      63
#      64
#
# C:\ProgramData\Anaconda3\envs\chip_allocate\lib\site-packages\shapely\geos.py in write(self, geom)
#     378         if geom is None or geom._geom is None:
#     379             raise ValueError("Null geometry supports no operations")
# --> 380         result = self._lgeos.GEOSWKTWriter_write(self._writer, geom._geom)
#     381         text = string_at(result)
#     382         lgeos.GEOSFree(result)
#
# OSError: exception: access violation writing 0x0000000000000000
